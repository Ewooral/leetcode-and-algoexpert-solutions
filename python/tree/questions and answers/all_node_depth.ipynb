# %%
import queue
from binarytree import Node

node = Node(1)

level_2_left = Node(2)
level_2_right = Node(3)
node.left = level_2_left
node.right = level_2_right

level_3_leftA = Node(4)
level_3_leftB = Node(5)
node.left.left = level_3_leftA
node.left.right = level_3_leftB

level_3_rightA = Node(6)
level_3_rightB = Node(7)
node.right.left = level_3_rightA
node.right.right = level_3_rightB


def insertAtLeft(root, node):
    if root is None:
        return
    else:
        q = queue.Queue()
        q.put(root)
        while not q.empty():
            rooty = q.get()
            if rooty.left is not None:
                q.put(rooty.left)
            else:
                rooty.left = node


def insertAtRight(root, node):
    if root is None:
        return
    else:
        q = queue.Queue()
        q.put(root)
        while not q.empty():
            rooty = q.get()
            if rooty.right is not None:
                q.put(rooty.right)
            else:
                rooty.right = node


insertAtLeft(node.left, Node(8))
insertAtRight(node.left.left, Node(9))


def printLeftTree(root):
    if root is None:
        return
    else:
        q = queue.Queue()
        q.put(root)
        while not q.empty():
            rooty = q.get()
            if rooty.left is not None:
                print( rooty.left)


def printRightTree(root):
    if root is None:
        return
    else:
        q = queue.Queue()
        q.put(root)
        while not q.empty():
            rooty = q.get()
            if rooty.right is not None:
                print(rooty.right)


def allKindOfNodeDepthsI(root):
    sumOfAllDepths = 0
    stack = [root]
    while len(stack) > 0:
        node = stack.pop()
        if node is None:
            continue
        sumOfAllDepths += nodeDepths(node)
        stack.append(node.left)
        stack.append(node.right)
    return sumOfAllDepths


def nodeDepths(node, depth=0):
    if node is None:
        return 0
    return depth + nodeDepths(node.left, depth + 1) + nodeDepths(node.right, depth + 1)


print(node)
print(node.is_balanced)
print(node)
print(node.leaf_count)
print(node.height)
print(allKindOfNodeDepthsI(node))

print("...Left sub tree...")
printLeftTree(node)
print("...right sub tree...")
printRightTree(node)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [8], in <cell line: 97>()
#      93         return 0
#      94     return depth + nodeDepths(node.left, depth + 1) + nodeDepths(node.right, depth + 1)
# ---> 97 print(node)
#      98 print(node.is_balanced)
#      99 print(node)
#
# File ~\.virtualenvs\Ewooral-Tutorials-i81cRfln\lib\site-packages\binarytree\__init__.py:174, in Node.__str__(self)
#     141 def __str__(self) -> str:
#     142     """Return the pretty-print string for the binary tree.
#     143
#     144     :return: Pretty-print string.
#    (...)
#     172         https://en.wikipedia.org/wiki/Tree_traversal#Breadth-first_search
#     173     """
# --> 174     lines = _build_tree_string(self, 0, False, "-")[0]
#     175     return "\n" + "\n".join((line.rstrip() for line in lines))
#
# File ~\.virtualenvs\Ewooral-Tutorials-i81cRfln\lib\site-packages\binarytree\__init__.py:1933, in _build_tree_string(root, curr_index, include_index, delimiter)
#    1930 new_root_width = gap_size = len(node_repr)
#    1932 # Get the left and right sub-boxes, their widths, and root repr positions
# -> 1933 l_box, l_box_width, l_root_start, l_root_end = _build_tree_string(
#    1934     root.left, 2 * curr_index + 1, include_index, delimiter
#    1935 )
#    1936 r_box, r_box_width, r_root_start, r_root_end = _build_tree_string(
#    1937     root.right, 2 * curr_index + 2, include_index, delimiter
#    1938 )
#    1940 # Draw the branch connecting the current root node to the left sub-box
#    1941 # Pad the line with whitespaces where necessary
#
# File ~\.virtualenvs\Ewooral-Tutorials-i81cRfln\lib\site-packages\binarytree\__init__.py:1933, in _build_tree_string(root, curr_index, include_index, delimiter)
#    1930 new_root_width = gap_size = len(node_repr)
#    1932 # Get the left and right sub-boxes, their widths, and root repr positions
# -> 1933 l_box, l_box_width, l_root_start, l_root_end = _build_tree_string(
#    1934     root.left, 2 * curr_index + 1, include_index, delimiter
#    1935 )
#    1936 r_box, r_box_width, r_root_start, r_root_end = _build_tree_string(
#    1937     root.right, 2 * curr_index + 2, include_index, delimiter
#    1938 )
#    1940 # Draw the branch connecting the current root node to the left sub-box
#    1941 # Pad the line with whitespaces where necessary
#
# File ~\.virtualenvs\Ewooral-Tutorials-i81cRfln\lib\site-packages\binarytree\__init__.py:1933, in _build_tree_string(root, curr_index, include_index, delimiter)
#    1930 new_root_width = gap_size = len(node_repr)
#    1932 # Get the left and right sub-boxes, their widths, and root repr positions
# -> 1933 l_box, l_box_width, l_root_start, l_root_end = _build_tree_string(
#    1934     root.left, 2 * curr_index + 1, include_index, delimiter
#    1935 )
#    1936 r_box, r_box_width, r_root_start, r_root_end = _build_tree_string(
#    1937     root.right, 2 * curr_index + 2, include_index, delimiter
#    1938 )
#    1940 # Draw the branch connecting the current root node to the left sub-box
#    1941 # Pad the line with whitespaces where necessary
#
# File ~\.virtualenvs\Ewooral-Tutorials-i81cRfln\lib\site-packages\binarytree\__init__.py:1930, in _build_tree_string(root, curr_index, include_index, delimiter)
#    1927 else:
#    1928     node_repr = str(root.val)
# -> 1930 new_root_width = gap_size = len(node_repr)
#    1932 # Get the left and right sub-boxes, their widths, and root repr positions
#    1933 l_box, l_box_width, l_root_start, l_root_end = _build_tree_string(
#    1934     root.left, 2 * curr_index + 1, include_index, delimiter
#    1935 )
#
# File ~\.virtualenvs\Ewooral-Tutorials-i81cRfln\lib\site-packages\binarytree\__init__.py:1930, in _build_tree_string(root, curr_index, include_index, delimiter)
#    1927 else:
#    1928     node_repr = str(root.val)
# -> 1930 new_root_width = gap_size = len(node_repr)
#    1932 # Get the left and right sub-boxes, their widths, and root repr positions
#    1933 l_box, l_box_width, l_root_start, l_root_end = _build_tree_string(
#    1934     root.left, 2 * curr_index + 1, include_index, delimiter
#    1935 )
#
# File _pydevd_bundle\pydevd_cython_win32_310_64.pyx:1179, in _pydevd_bundle.pydevd_cython_win32_310_64.SafeCallWrapper.__call__()
#
# File _pydevd_bundle\pydevd_cython_win32_310_64.pyx:620, in _pydevd_bundle.pydevd_cython_win32_310_64.PyDBFrame.trace_dispatch()
#
# File _pydevd_bundle\pydevd_cython_win32_310_64.pyx:1095, in _pydevd_bundle.pydevd_cython_win32_310_64.PyDBFrame.trace_dispatch()
#
# File _pydevd_bundle\pydevd_cython_win32_310_64.pyx:1053, in _pydevd_bundle.pydevd_cython_win32_310_64.PyDBFrame.trace_dispatch()
#
# File C:\Program Files\JetBrains\PyCharm 2022.1\plugins\python\helpers-pro\jupyter_debug\pydev_jupyter_plugin.py:165, in stop(plugin, pydb, frame, event, args, stop_info, arg, step_cmd)
#     163     frame = suspend_jupyter(main_debugger, thread, frame, step_cmd)
#     164     if frame:
# --> 165         main_debugger.do_wait_suspend(thread, frame, event, arg)
#     166         return True
#     167 return False
#
# File C:\Program Files\JetBrains\PyCharm 2022.1\plugins\python\helpers\pydev\pydevd.py:1155, in PyDB.do_wait_suspend(self, thread, frame, event, arg, send_suspend_message, is_unhandled_exception)
#    1152         from_this_thread.append(frame_id)
#    1154 with self._threads_suspended_single_notification.notify_thread_suspended(thread_id, stop_reason):
# -> 1155     self._do_wait_suspend(thread, frame, event, arg, suspend_type, from_this_thread)
#
# File C:\Program Files\JetBrains\PyCharm 2022.1\plugins\python\helpers\pydev\pydevd.py:1170, in PyDB._do_wait_suspend(self, thread, frame, event, arg, suspend_type, from_this_thread)
#    1167             self._call_mpl_hook()
#    1169         self.process_internal_commands()
# -> 1170         time.sleep(0.01)
#    1172 self.cancel_async_evaluation(get_current_thread_id(thread), str(id(frame)))
#    1174 # process any stepping instructions
#
# KeyboardInterrupt:
